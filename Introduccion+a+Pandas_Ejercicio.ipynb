# %%
# importar pandas
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Opcional: usa el pd.set_option() para mostrar todas las filas de un dataframe por defecto

# %% [markdown]
# # Crear un DataFrame

# %%
# leer el archivo csv "bestsellers with categories" (data sobre los 50 libros más vendidos de Amazon de 2009 a 201
df_bestsellers=pd.read_csv('/content/drive/MyDrive/bestsellers+with+categories.csv')

# %%
# acceder al atributo shape
df_bestsellers.shape
# Out:
# (550, 7)

# %%
# encontrar el tipo de data de cada columna
df_bestsellers.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Mostrar un DataFrame

# %%
# mostrar primeras 5 filas de un dataframe
df_bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# encontrar valores estadisticos de un dataframe (mean, std, min, max)
df_bestsellers.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Agregar una nueva Columna

# %%
# Tu tarea es crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4

# 1.importar numpy y crear 550 numeros random enteros entre 1 y 4
import pandas as pd
import numpy as np
Critic_Rating=np.random.randint(1, 4, size=550)
critic_nota=pd.Series(Critic_Rating, index=np.arange(0, 550))
# 2.agregar nueva columna 'Critic Rating' al dataframe usando los numeros random creados
df_bestsellers.assign(Critic_Rating=critic_nota)
df_bestsellers=df_bestsellers.assign(Critic_Rating=critic_nota)
# Obs: Los numeros aleatorios en la columna 'Critic Rating' seran diferentes entre tu solucion y la mia, pero vamos a concetrarnos en el codigo en esta seccion.

# %%
df_bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic_Rating
# 0                2
# 1                3
# 2                3
# 3                3
# 4                3
# ..             ...
# 545              1
# 546              1
# 547              3
# 548              1
# 549              3
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
df_bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic_Rating
# 0              2
# 1              3
# 2              3
# 3              3
# 4              3

# %% [markdown]
# # Atributos, Metodos y Funciones Basicas

# %%
# acceder al atributo "columns"
df_bestsellers.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic_Rating'],
#       dtype='object')

# %% [markdown]
# # Seleccionar 2 o Mas Columnas de un Dataframe

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" Luego actualizar el dataframe
df_bestsellers
df_bestsellers.drop(columns='Critic_Rating')
df_bestsellers=df_bestsellers.loc[:, ['Name', 'Author', 'User Rating', 'Critic_Rating', 'Reviews', 'Price', 'Year', 'Genre']]
df_bestsellers
# Tip: Copiar y pegar los nombres de columna obtenidos con el atributo "columns" y reordenar los elementos usando [[]]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic_Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              2    17350      8
# 1                Stephen King          4.6              3     2052     22
# 2          Jordan B. Peterson          4.7              3    18979     15
# 3               George Orwell          4.7              3    21424      6
# 4    National Geographic Kids          4.8              3     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9              1     9413      8
# 546               Jen Sincero          4.7              1    14331      8
# 547               Jen Sincero          4.7              3    14331      8
# 548               Jen Sincero          4.7              1    14331      8
# 549               Jen Sincero          4.7              3    14331      8
#
#      Year        Genre
# 0    2016  Non Fiction
# 1    2011      Fiction
# 2    2018  Non Fiction
# 3    2017      Fiction
# 4    2019  Non Fiction
# ..    ...          ...
# 545  2019      Fiction
# 546  2016  Non Fiction
# 547  2017  Non Fiction
# 548  2018  Non Fiction
# 549  2019  Non Fiction
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
df_bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Critic_Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              2    17350      8  2016
# 1              Stephen King          4.6              3     2052     22  2011
# 2        Jordan B. Peterson          4.7              3    18979     15  2018
# 3             George Orwell          4.7              3    21424      6  2017
# 4  National Geographic Kids          4.8              3     7665     12  2019
#
#          Genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction
# 4  Non Fiction

# %% [markdown]
# # Operaciones en Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rating = (User Rating + Critic Rating)/2
df_bestsellers['Average Rating']=(df_bestsellers['User Rating']+df_bestsellers['Critic_Rating'])/2

# %%
# usar la funcion "round" para redondear los valores del dataframe a 1 decimal y actualizar el dataframe
round(df_bestsellers)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic_Rating  Reviews  Price  \
# 0                    JJ Smith          5.0              2    17350      8
# 1                Stephen King          5.0              3     2052     22
# 2          Jordan B. Peterson          5.0              3    18979     15
# 3               George Orwell          5.0              3    21424      6
# 4    National Geographic Kids          5.0              3     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          5.0              1     9413      8
# 546               Jen Sincero          5.0              1    14331      8
# 547               Jen Sincero          5.0              3    14331      8
# 548               Jen Sincero          5.0              1    14331      8
# 549               Jen Sincero          5.0              3    14331      8
#
#      Year        Genre  Average Rating
# 0    2016  Non Fiction             3.0
# 1    2011      Fiction             4.0
# 2    2018  Non Fiction             4.0
# 3    2017      Fiction             4.0
# 4    2019  Non Fiction             4.0
# ..    ...          ...             ...
# 545  2019      Fiction             3.0
# 546  2016  Non Fiction             3.0
# 547  2017  Non Fiction             4.0
# 548  2018  Non Fiction             3.0
# 549  2019  Non Fiction             4.0
#
# [550 rows x 9 columns]

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa
df_bestsellers['Genre'].value_counts()
# Out:
# Genre
# Non Fiction    310
# Fiction        240
# Name: count, dtype: int64

# %% [markdown]
# # Renombrar Columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
df_bestsellers=df_bestsellers.rename(columns={'User Rating':'UR', 'Critic_Rating':'CR', 'Average Rating':'AR'})
df_bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR  Reviews  Price  Year        Genre  \
# 0                    JJ Smith  4.7   2    17350      8  2016  Non Fiction
# 1                Stephen King  4.6   3     2052     22  2011      Fiction
# 2          Jordan B. Peterson  4.7   3    18979     15  2018  Non Fiction
# 3               George Orwell  4.7   3    21424      6  2017      Fiction
# 4    National Geographic Kids  4.8   3     7665     12  2019  Non Fiction
# ..                        ...  ...  ..      ...    ...   ...          ...
# 545               Jeff Kinney  4.9   1     9413      8  2019      Fiction
# 546               Jen Sincero  4.7   1    14331      8  2016  Non Fiction
# 547               Jen Sincero  4.7   3    14331      8  2017  Non Fiction
# 548               Jen Sincero  4.7   1    14331      8  2018  Non Fiction
# 549               Jen Sincero  4.7   3    14331      8  2019  Non Fiction
#
#        AR
# 0    3.35
# 1    3.80
# 2    3.85
# 3    3.85
# 4    3.90
# ..    ...
# 545  2.95
# 546  2.85
# 547  3.85
# 548  2.85
# 549  3.85
#
# [550 rows x 9 columns]

# %%
# mostrar 5 primeras filas
df_bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  CR  Reviews  Price  Year        Genre    AR
# 0                  JJ Smith  4.7   2    17350      8  2016  Non Fiction  3.35
# 1              Stephen King  4.6   3     2052     22  2011      Fiction  3.80
# 2        Jordan B. Peterson  4.7   3    18979     15  2018  Non Fiction  3.85
# 3             George Orwell  4.7   3    21424      6  2017      Fiction  3.85
# 4  National Geographic Kids  4.8   3     7665     12  2019  Non Fiction  3.90

# %%
# seleccionar solo columnas "Name", "Author", "UR", "CR", "AR" y "Year" y actualizar el dataframe
df_bestsellers[['Name', 'Author', 'UR', 'CR', 'AR', 'Year']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR    AR  Year
# 0                    JJ Smith  4.7   2  3.35  2016
# 1                Stephen King  4.6   3  3.80  2011
# 2          Jordan B. Peterson  4.7   3  3.85  2018
# 3               George Orwell  4.7   3  3.85  2017
# 4    National Geographic Kids  4.8   3  3.90  2019
# ..                        ...  ...  ..   ...   ...
# 545               Jeff Kinney  4.9   1  2.95  2019
# 546               Jen Sincero  4.7   1  2.85  2016
# 547               Jen Sincero  4.7   3  3.85  2017
# 548               Jen Sincero  4.7   1  2.85  2018
# 549               Jen Sincero  4.7   3  3.85  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
df_bestsellers.sort_values(['UR', 'CR'], ascending=False)
# Out:
#                                                   Name                Author  \
# 41            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 146  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 151                           Hamilton: The Revolution    Lin-Manuel Miranda
# 157  Harry Potter and the Sorcerer's Stone: The Ill...          J.K. Rowling
# 188  Jesus Calling: Enjoying Peace in His Presence ...           Sarah Young
# ..                                                 ...                   ...
# 22                                           Allegiant         Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 132                         Go Set a Watchman: A Novel            Harper Lee
# 353                                 The Casual Vacancy          J.K. Rowling
#
#       UR  CR  Reviews  Price  Year        Genre    AR
# 41   4.9   3    14344      5  2019      Fiction  3.95
# 146  4.9   3     7038      7  2012      Fiction  3.95
# 151  4.9   3     5867     54  2016  Non Fiction  3.95
# 157  4.9   3    10052     22  2016      Fiction  3.95
# 188  4.9   3    19576      8  2012  Non Fiction  3.95
# ..   ...  ..      ...    ...   ...          ...   ...
# 22   3.9   1     6310     13  2013      Fiction  2.45
# 107  3.8   3    47265     14  2013      Fiction  3.40
# 106  3.8   2    47265     14  2012      Fiction  2.90
# 132  3.6   1    14982     19  2015      Fiction  2.30
# 353  3.3   2     9372     12  2012      Fiction  2.65
#
# [550 rows x 9 columns]
